# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods
# ## 1. Introduction/Business Problem section
# A short description of the business problem and the target audience interested
# My business partner and I would like to initiate a startup business to provide indoor rock climbing facilities in Singapore. We have looked through a list of locations provided by our property consultant and narrowed down our preferred choice to 5 locations based on their rental prices.
#
# Aside from rental prices, we would also like to take reference from the characteristics (e.g near public transport facilities, food outlets etc) of our competitors' location to select our choice of venue.
#
# My partner has asked for my help to find out how many of such similar rock climbing facilities are in Singapore and where they are located. Leveraging on the skills I have learnt in this course on using Foursquare location API, I would be identifying the characteristics of the venues surrounding our competitors' facilities (e.g public transport facilities and food outlets). Subsequently, based on what we know of our competitors' venue, we would then apply the characteristics to our list of shortlisted venues to make our decision.

# %% [markdown]
# ## 2. Data section
# Description of the data and its sources that will be used to solve the problem
# ### 2.1 Data on existing rock climbing facilities in Singapore and their location
#
# To identify the characteristics of our competitors' venues in Singapore, we would first need to find out the number of rock climbing facilities in Singapore currently and their location. We have found a list of popular rock climbing facilities in Singapore from the website thehoneycombers.com and obtained their postal code addresses.
#
# Next, we would be using Google Map API to find their geographic coordinates based on their postal code addresses.

# %%
# !pip install beautifulsoup4
# !pip install lxml
# !pip install html5lib
# !pip install requests
# !pip install geocoder

from bs4 import BeautifulSoup
import requests
import csv
import json
import xml
import pandas as pd

print("Installed successfully!")
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\dell\anaconda3\lib\site-packages (4.7.1)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\dell\anaconda3\lib\site-packages (from beautifulsoup4) (1.8)
# Requirement already satisfied: lxml in c:\users\dell\anaconda3\lib\site-packages (4.3.2)
# Requirement already satisfied: html5lib in c:\users\dell\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: webencodings in c:\users\dell\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\dell\anaconda3\lib\site-packages (from html5lib) (1.12.0)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (2.21.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\dell\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests) (2019.3.9)
# Requirement already satisfied: geocoder in c:\users\dell\anaconda3\lib\site-packages (1.38.1)
# Requirement already satisfied: future in c:\users\dell\anaconda3\lib\site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: click in c:\users\dell\anaconda3\lib\site-packages (from geocoder) (7.0)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (from geocoder) (2.21.0)
# Requirement already satisfied: six in c:\users\dell\anaconda3\lib\site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: ratelim in c:\users\dell\anaconda3\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests->geocoder) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\dell\anaconda3\lib\site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests->geocoder) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: decorator in c:\users\dell\anaconda3\lib\site-packages (from ratelim->geocoder) (4.4.0)
# Installed successfully!

# %%
# To crawl the website for competitors' names and address
res = requests.get("https://thehoneycombers.com/singapore/rock-climbing-in-singapore-conquer-this-extreme-sport-at-these-best-indoor-climbing-walls-and-bouldering-gyms/")
df_rock_climbing = BeautifulSoup(res.content,'lxml')

# %%
col_names = ['Name','Address']
df_climbing = pd.DataFrame(columns = col_names)
pd.set_option('display.max_colwidth', 0)

name = 0
address = 0

# To extract names of comeptitor and their addresses and store as dataframe
content = df_rock_climbing.find('div', class_='entry-content')

for para in content.find_all('p'):
    i = 0  
    if i == 0:
        for outlets in para.find_all(['b','strong']):
            name = outlets.text.strip('\n').replace('.','')
            
        for add in para.find_all(['i','em']):
            address = add.text.strip('\n').replace(',','')
            
            i = i + 1
            
    df_climbing = df_climbing.append({'Name': name, 'Address': address},ignore_index=True) 

# Duplicates and invalid rows are dropped
df_climbing.drop_duplicates(subset=['Address'], keep='first', inplace=False)
df_climbing = df_climbing[3:15].reset_index(drop=True)

df_climbing.head(15)
# Out:
#                                  Name  \
# 0   Let ‘em Play
# 1   Oyeyo Boulder Home
# 2   Boulder Movement
# 3   Climbers Laboratory
# 4   Onsight Climbing
# 5   Climb Central
# 6   Kinetics Climbing
# 7   Climb Asia
# 8   The Rock School
# 9   SAFRA Adventure Sports Centre
# 10  Clip ‘n Climb HomeTeamNS
# 11  Like this story? Check these out:
#
#                                                                                                                   Address
# 0    #01-100 18 Boon Lay Way Singapore 609966 p. 6266 6125
# 1    148 Mackenzie Road Singapore 228724
# 2    #B1-03 OUE Downtown Gallery 6A Shenton Way Singapore 068815
# 3    #05-153 Enterprise Hub 48 Toh Guan Road East Singapore 608586 p. 6515 9363
# 4    100 Guillemard Road Singapore 399718 p. 6348 8272
# 5    #B1-01 Kallang Wave Mall 1 Stadium Place Singapore 397718 p. 6702 7972
# 6    #02-07 Orion @ Paya Lebar 160 Paya Lebar Road Singapore 409022 p. 6745 6426
# 7    60 Tessensohn Road Singapore 217664 p. 6292 7701
# 8    850 New Upper Changi Road Singapore 467352 p. 6242 2106
# 9    60 Yishun Avenue 4 Singapore 769027 p. 6852 8222
# 10  Clip ’n Climb HomeTeam NS HomeTeamNS Tampines 51 Tampines Ave 4 #03-03 Our Tampines Hub Singapore 529684 p. 6705 9410
# 11  Clip ’n Climb HomeTeam NS HomeTeamNS Tampines 51 Tampines Ave 4 #03-03 Our Tampines Hub Singapore 529684 p. 6705 9410

# %%
# To create a new postalcode field from address field
df_climbing['Postalcode'] = df_climbing['Address'].str.extract('(\d\d\d\d\d\d)', expand=True)
df_climbing.head()
# Out:
#                   Name  \
# 0  Let ‘em Play
# 1  Oyeyo Boulder Home
# 2  Boulder Movement
# 3  Climbers Laboratory
# 4  Onsight Climbing
#
#                                                                        Address  \
# 0   #01-100 18 Boon Lay Way Singapore 609966 p. 6266 6125
# 1   148 Mackenzie Road Singapore 228724
# 2   #B1-03 OUE Downtown Gallery 6A Shenton Way Singapore 068815
# 3   #05-153 Enterprise Hub 48 Toh Guan Road East Singapore 608586 p. 6515 9363
# 4   100 Guillemard Road Singapore 399718 p. 6348 8272
#
#   Postalcode
# 0  609966
# 1  228724
# 2  068815
# 3  608586
# 4  399718

# %%
# @hidden_cell
GOOGLE_API_KEY='AIzaSyAQWqMTOcyLBRDR2skO4F_5QEWzNDOlUHw'

# %%
# Obtain the Latitude and Longitude of each competitor's venue using Geocoder and Google API
import geocoder

# Define function to get latitude and longitude
def get_latlng(postal_code):
    lat_lng_coords = None
    while(lat_lng_coords is None):
        g = geocoder.google('{}, Singapore'.format(postal_code), key=GOOGLE_API_KEY)
        lat_lng_coords = g.latlng
    return lat_lng_coords

# Insert new column of latitude and logitude into dataframe
postal_codes1 = df_climbing['Postalcode']    
coords = [ get_latlng(postal_code) for postal_code in postal_codes1.tolist() ]

df_climbing_coords = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])
df_climbing['Latitude'] = df_climbing_coords['Latitude']
df_climbing['Longitude'] = df_climbing_coords['Longitude']
df_climbing.head(15)
# Out:
#                                  Name  \
# 0   Let ‘em Play
# 1   Oyeyo Boulder Home
# 2   Boulder Movement
# 3   Climbers Laboratory
# 4   Onsight Climbing
# 5   Climb Central
# 6   Kinetics Climbing
# 7   Climb Asia
# 8   The Rock School
# 9   SAFRA Adventure Sports Centre
# 10  Clip ‘n Climb HomeTeamNS
# 11  Like this story? Check these out:
#
#                                                                                                                   Address  \
# 0    #01-100 18 Boon Lay Way Singapore 609966 p. 6266 6125
# 1    148 Mackenzie Road Singapore 228724
# 2    #B1-03 OUE Downtown Gallery 6A Shenton Way Singapore 068815
# 3    #05-153 Enterprise Hub 48 Toh Guan Road East Singapore 608586 p. 6515 9363
# 4    100 Guillemard Road Singapore 399718 p. 6348 8272
# 5    #B1-01 Kallang Wave Mall 1 Stadium Place Singapore 397718 p. 6702 7972
# 6    #02-07 Orion @ Paya Lebar 160 Paya Lebar Road Singapore 409022 p. 6745 6426
# 7    60 Tessensohn Road Singapore 217664 p. 6292 7701
# 8    850 New Upper Changi Road Singapore 467352 p. 6242 2106
# 9    60 Yishun Avenue 4 Singapore 769027 p. 6852 8222
# 10  Clip ’n Climb HomeTeam NS HomeTeamNS Tampines 51 Tampines Ave 4 #03-03 Our Tampines Hub Singapore 529684 p. 6705 9410
# 11  Clip ’n Climb HomeTeam NS HomeTeamNS Tampines 51 Tampines Ave 4 #03-03 Our Tampines Hub Singapore 529684 p. 6705 9410
#
#    Postalcode  Latitude   Longitude
# 0   609966     1.328234  103.753597
# 1   228724     1.306886  103.846657
# 2   068815     1.276557  103.848227
# 3   608586     1.337078  103.754725
# 4   399718     1.310077  103.881833
# 5   397718     1.303242  103.874757
# 6   409022     1.329320  103.890342
# 7   217664     1.315722  103.856214
# 8   467352     1.324349  103.935899
# 9   769027     1.423708  103.840650
# 10  529684     1.353284  103.941340
# 11  529684     1.353284  103.941340

# %% [markdown]
# ### 2.2 Data on geographic coordinates of the 5 shortlisted locations
#
# We have also prepared a datset of the addresses of the 5 locations we have shortlisted. Using Google Map API, we extracted their geographic coordinates based on their postal code addresses

# %%
# To list the 5 locations we have shortlisted
shortlisted_locations = [
    { 'Location': 'L1', 'Address': 'The Grandstand, 200 Turf Club Rd','Postalcode': '287994'},
    { 'Location': 'L2', 'Address': 'IMM, 2 Jurong East Street 21','Postalcode': '609601'},
    { 'Location': 'L3', 'Address': 'KINEX, 11 Tanjong Katong Rd','Postalcode': '437157'},
    { 'Location': 'L4', 'Address': 'The Star Vista, 1 Vista Exchange Green','Postalcode': '138617'}, 
    { 'Location': 'L5', 'Address': 'Causeway Point, 1 Woodlands Square','Postalcode': '738099'},
]

# %%
# Extract latitude and logitude details and create dataframe for the 5 shortlisted locations
for loc in shortlisted_locations:        
    (lat, lng) = get_latlng(loc['Address'])
    loc['Latitude'] = lat
    loc['Longitude'] = lng
    
df_shortlisted_locations = pd.DataFrame(shortlisted_locations, columns=['Location', 'Address', 'Latitude', 'Longitude'])
df_shortlisted_locations
# Out:
#   Location                                 Address  Latitude   Longitude
# 0  L1       The Grandstand, 200 Turf Club Rd        1.337892  103.793338
# 1  L2       IMM, 2 Jurong East Street 21            1.334815  103.746839
# 2  L3       KINEX, 11 Tanjong Katong Rd             1.314762  103.894726
# 3  L4       The Star Vista, 1 Vista Exchange Green  1.306763  103.788424
# 4  L5       Causeway Point, 1 Woodlands Square      1.435984  103.786013

# %% [markdown]
# ### 2.3 Data on transportation, food and other amenities around competitors' venue
#
# We expect our competitors' venues to be located in areas with good access to public transportation (Train stations / Bus-Stops), food outlets (fast-food chains / cafes / restaurants) and retail shopping outlets. We would be using Foursquare API to find out what are the services around our competitors' venue for comparison. The radius of exploration distance is set at 350 meters, which is about 5 minutes walking distance.

# %%
# Types of services that we would like to examine
services_categories = {
    'Food': '4d4b7105d754a06374d81259',
    'Shop & Service': '4d4b7105d754a06378d81259',
    'Bus Stop': '52f2ab2ebcbc57f1066b8b4f',
    'Metro Station': '4bf58dd8d48988d1fd931735',
}

# %%
# To create a list of services that we would like to examine
', '.join([cat for cat in services_categories])
# Out:
# 'Food, Shop & Service, Bus Stop, Metro Station'

# %%
# Use the one of competitors as example to explore the services nearby within 350m
climb_venue = df_climbing.loc[7]
print(climb_venue)
# Out:
# Name          Climb Asia
# Address        60 Tessensohn Road Singapore 217664 p. 6292 7701
# Postalcode    217664
# Latitude      1.31572
# Longitude     103.856
# Name: 7, dtype: object

# %%
# Install FourSquare client library
# !pip install foursquare
# Out:
# Collecting foursquare
#   Downloading https://files.pythonhosted.org/packages/a2/fc/825326248f9caf7c19a58dede1b7f1604573e998dd6f6003cba1701215db/foursquare-1%212019.2.16.tar.gz
# Requirement already satisfied: requests>=2.1 in c:\users\dell\anaconda3\lib\site-packages (from foursquare) (2.21.0)
# Requirement already satisfied: six in c:\users\dell\anaconda3\lib\site-packages (from foursquare) (1.12.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.1->foursquare) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.1->foursquare) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.1->foursquare) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.1->foursquare) (3.0.4)
# Building wheels for collected packages: foursquare
#   Building wheel for foursquare (setup.py): started
#   Building wheel for foursquare (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\dell\AppData\Local\pip\Cache\wheels\50\82\db\97c078881efb89f4e89560487926fbadfff87a40e5fe41f6fb
# Successfully built foursquare
# Installing collected packages: foursquare
# Successfully installed foursquare-1!2019.2.16

# %%
import foursquare
from pandas.io.json import json_normalize

# %%
CLIENT_ID = 'HYZOMBRA5G0YW21COJDI54SFQGPMUUEFLK4K3G13VQPJSAWV' # Foursquare ID
CLIENT_SECRET = 'A521L4H105S0RTC3DMAMXJXMAUTVYMFRERFJWOMJWZLXC4UG' # Foursquare Secret
VERSION = '20190605' # Foursquare API version

# %%
fs = foursquare.Foursquare(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)

# %%
# Define a function to search nearby information and convert the result as dataframe
RADIUS = 350

def venues_nearby(latitude, longitude, category, verbose=True):    
    results = fs.venues.search(
        params = {
            'query': category, 
            'll': '{},{}'.format(latitude, longitude),
            'radius': RADIUS,
            'categoryId': services_categories[category]
        }
    )
    df = json_normalize(results['venues'])
    cols = ['Name','Latitude','Longitude']    
    if( len(df) == 0 ):        
        df = pd.DataFrame(columns=cols)
    else:        
       df = df[['name','location.lat','location.lng',]]
       df.columns = cols
    if( verbose ):
        print('{} "{}" venues are found within {}m of location'.format(len(df), category, RADIUS))
    return df

# %%
# Metro station around the venue of our sample of competitor
venues_nearby(climb_venue['Latitude'], climb_venue['Longitude'], 'Metro Station').head()
# Out:
# 1 "Metro Station" venues are found within 350m of location
#                             Name  Latitude   Longitude
# 0  Farrer Park MRT Station (NE8)  1.312751  103.854618

# %%
# Bus stops around the venue of our sample of competitor
venues_nearby(climb_venue['Latitude'], climb_venue['Longitude'], 'Bus Stop').head()
# Out:
# 1 "Bus Stop" venues are found within 350m of location
#                                       Name  Latitude   Longitude
# 0  Bus Stop 50241 (Opp S'pore Khalsa Assn)  1.317234  103.857331

# %%
# Food outlets around the venue of our sample of competitor
venues_nearby(climb_venue['Latitude'], climb_venue['Longitude'], 'Food').head()
# Out:
# 6 "Food" venues are found within 350m of location
#                                  Name  Latitude   Longitude
# 0  Food Truck                          1.315890  103.859091
# 1  P&p Thai Food @ Upp Serangoon Road  1.314611  103.857309
# 2  9-9 Food & Beverages                1.314578  103.854003
# 3  Li Yuan Food Court                  1.315636  103.859320
# 4  Al-Habib Muslim Food                1.318769  103.857155

# %%
# Retail shopping outlets around the venue of our sample of competitor
venues_nearby(climb_venue['Latitude'], climb_venue['Longitude'], 'Shop & Service').head()
# Out:
# 5 "Shop & Service" venues are found within 350m of location
#                                       Name  Latitude   Longitude
# 0  Tan Bike Shop                            1.314882  103.852233
# 1  Sinar Bintang Barber Shop                1.313912  103.855468
# 2  Hardware Shop                            1.314409  103.857498
# 3  Rangoon Provision Shop                   1.314224  103.855040
# 4  Chua Tiong Lim Pte Ltd - Provision Shop  1.315138  103.858961

# %% [markdown]
# ## 3. Methodology Section¶
# With the data prepared in Section 2: Data Section, we would proceed to select the most optimal location out of the 5 locations shortlisted for our company's indoor rock climbing facility. Using Foursquare API, we would be able find out the number of venues (metro stations, bus stops, food outlets and retail shopping outlets) around each of our competitors' locations (within <350m) and build a matrix to captured the characteristics of the venues surrounding their rock climbing facilities.
#
# Thereafter, a weighted matrix would be developed to rank the 5 locations shortlisted and the top result would be the most ideal location for our rock climbing facility.
#
# ### 3.1 Data Transformation

# %%
# Create a new dataframe to include the venues nearby (<350m) for each competitor's location 
df_venues = pd.DataFrame(columns=['Outlet Name', 'Category', 'Name', 'Latitude', 'Longitude', 'Tips', 'Users', 'Visits'])
for (name, address, postalcode, latitude, longitude) in df_climbing.itertuples(index=False):
    for cat, cat_id in services_categories.items():
        df = venues_nearby(latitude, longitude, cat, verbose=False)
        df['Outlet Name'] = name
        df['Category'] = cat
        df_venues = df_venues.append(df, sort=True)

# %%
# To check the number of venues extracted based on the dataframe of competitors' location
print('Total {} of venues are found'.format(len(df_venues)))
# Out:
# Total 253 of venues are found

# %%
# To check the shape of dataframe
df_venues.shape
# Out:
# (253, 8)

# %%
# Sample check on the first 10 rows of the new dataframe
df_venues.head(10)
# Out:
#          Category  Latitude   Longitude                              Name  \
# 0  Food            1.327928  103.752408  bernas food corner
# 1  Food            1.328363  103.752289  Choh Dee Place
# 0  Shop & Service  1.328558  103.752302  My Golf Shop @ Trade Hub
# 1  Shop & Service  1.328046  103.752990  Buy & Fix
# 2  Shop & Service  1.328714  103.752317  Clout Shoppe Ptd Ltd
# 0  Bus Stop        1.327776  103.753593  Bus Stop 28029 @ Boon Lay Way
# 1  Bus Stop        1.327322  103.752279  Bus Stop 28031 (Bef The Synergy)
# 0  Food            1.309488  103.844862  Saybons French Food Factory
# 1  Food            1.306066  103.850353  Street Food
# 2  Food            1.308624  103.847277  i Think food
#
#           Outlet Name Tips Users Visits
# 0  Let ‘em Play        NaN  NaN   NaN
# 1  Let ‘em Play        NaN  NaN   NaN
# 0  Let ‘em Play        NaN  NaN   NaN
# 1  Let ‘em Play        NaN  NaN   NaN
# 2  Let ‘em Play        NaN  NaN   NaN
# 0  Let ‘em Play        NaN  NaN   NaN
# 1  Let ‘em Play        NaN  NaN   NaN
# 0  Oyeyo Boulder Home  NaN  NaN   NaN
# 1  Oyeyo Boulder Home  NaN  NaN   NaN
# 2  Oyeyo Boulder Home  NaN  NaN   NaN

# %%
# Summary on the total number of venues extracted for each category 
df_venues['Category'].value_counts().to_frame(name='Count')
# Out:
#                 Count
# Food            146
# Shop & Service  67
# Bus Stop        35
# Metro Station   5

# %%
# To drop the columns Tips, Users and Vists since they would not be required for our analysis
df_venues.drop(columns=['Tips','Users','Visits'], inplace=True)

# %%
# To check the shape of revised dataframe
df_venues.shape
# Out:
# (253, 5)

# %% [markdown]
# Next, we would be exploring the nearby venues of the 5 locations we have shortlisted using the same methodology

# %%
df_shortlisted_venues = pd.DataFrame(columns=['Location', 'Category', 'Name', 'Latitude', 'Longitude', 'Tips', 'Users', 'Visits'])
for (location, address, latitude, longitude) in df_shortlisted_locations.itertuples(index=False):
    for cat, cat_id in services_categories.items():
        df = venues_nearby(latitude, longitude, cat, verbose=False)
        df['Location'] = location
        df['Category'] = cat
        df_shortlisted_venues = df_shortlisted_venues.append(df, sort=True)

# %%
# To check the number of venues extracted based on the dataframe of shortlisted locations
print('Total {} of venues are found'.format(len(df_shortlisted_venues)))
# Out:
# Total 122 of venues are found

# %%
# To check the shape of dataframe
df_shortlisted_venues.shape
# Out:
# (122, 8)

# %%
# Sample check on the first 10 rows of the new dataframe for shortlisted venues
df_shortlisted_venues.head(10)
# Out:
#   Category  Latitude Location   Longitude                               Name  \
# 0  Food     1.337761  L1       103.793488  Let's eat! Food Court
# 0  Food     1.332169  L2       103.743741  Food Street | Big Box
# 1  Food     1.335168  L2       103.746283  Food Kaki
# 2  Food     1.334525  L2       103.746128  Ah May Foodcourt
# 3  Food     1.332443  L2       103.746875  Food Inn Eating House
# 4  Food     1.334966  L2       103.745586  FLO - Food Lovers Only
# 5  Food     1.333625  L2       103.748187  Pre Food Haven
# 6  Food     1.333368  L2       103.744668  Japanese and Korean Food  (Halal)
# 7  Food     1.336810  L2       103.744270  Red Hill 75 Food Court
# 8  Food     1.334316  L2       103.745924  Kopitiam
#
#   Tips Users Visits
# 0  NaN  NaN   NaN
# 0  NaN  NaN   NaN
# 1  NaN  NaN   NaN
# 2  NaN  NaN   NaN
# 3  NaN  NaN   NaN
# 4  NaN  NaN   NaN
# 5  NaN  NaN   NaN
# 6  NaN  NaN   NaN
# 7  NaN  NaN   NaN
# 8  NaN  NaN   NaN

# %%
# Summary on the total number of venues extracted for each category 
df_shortlisted_venues['Category'].value_counts().to_frame(name='Count')
# Out:
#                 Count
# Food            68
# Shop & Service  38
# Bus Stop        14
# Metro Station   2

# %%
# To drop the columns Tips, Users and Vists since they would not be required for our analysis
df_shortlisted_venues.drop(columns=['Tips','Users','Visits'], inplace=True)

# %%
# To check the shape of revised dataframe
df_shortlisted_venues.shape
# Out:
# (122, 5)

# %%
# Reshape dataframe to group number of nearby venues per competitor's location
df_venues_count = df_venues.groupby(['Outlet Name','Category'], as_index=False).count()
df_venues_count.drop(columns=['Latitude','Longitude'], inplace=True)
df_venues_count.rename(columns={'Name':'Count'}, inplace=True)
df_venues_count.head()
# Out:
#         Outlet Name        Category  Count
# 0  Boulder Movement  Bus Stop        6
# 1  Boulder Movement  Food            30
# 2  Boulder Movement  Metro Station   1
# 3  Boulder Movement  Shop & Service  6
# 4  Climb Asia        Bus Stop        1

# %%
#Reshape dataframe to wide format and fill blanks with 0 as values in the process
df_venues_count = df_venues_count.pivot(index='Outlet Name', columns='Category', values='Count').fillna(0)
df_venues_count.head()
# Out:
# Category                  Bus Stop  Food  Metro Station  Shop & Service
# Outlet Name
# Boulder Movement          6.0       30.0  1.0            6.0
# Climb Asia                1.0       6.0   1.0            5.0
# Climb Central             1.0       1.0   1.0            1.0
# Climbers Laboratory       3.0       5.0   0.0            2.0
# Clip ‘n Climb HomeTeamNS  4.0       18.0  0.0            14.0

# %%
# Likewise reshaping the dataframe for shortlisted locations
df_shortlisted_venues_count = df_shortlisted_venues.groupby(['Location','Category']).size().reset_index(name='Count')
df_shortlisted_venues_count = df_shortlisted_venues_count.pivot(index='Location', columns='Category', values='Count').fillna(0)
df_shortlisted_venues_count
# Out:
# Category  Bus Stop  Food  Metro Station  Shop & Service
# Location
# L1        0.0       1.0   0.0            0.0
# L2        3.0       13.0  0.0            8.0
# L3        6.0       30.0  0.0            6.0
# L4        3.0       10.0  1.0            8.0
# L5        2.0       14.0  1.0            16.0

# %% [markdown]
# ### 3.2 Data Analysis

# %%
# !conda install seaborn=0.9 --yes
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\dell\Anaconda3
#
#   added / updated specs:
#     - seaborn=0.9
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.3.9           |           py37_0         155 KB
#     ------------------------------------------------------------
#                                            Total:         155 KB
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi                                       conda-forge --> pkgs/main
#   conda                     conda-forge::conda-4.7.5-py37_0 --> pkgs/main::conda-4.6.14-py37_0
#
#
#
# Downloading and Extracting Packages
#
# certifi-2019.3.9     | 155 KB    |            |   0%
# certifi-2019.3.9     | 155 KB    | #          |  10%
# certifi-2019.3.9     | 155 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# WARNING conda.base.context:use_only_tar_bz2(632): Conda is constrained to only using the old .tar.bz2 file format because you have conda-build installed, and it is <3.18.3.  Update or remove conda-build to get smaller downloads and faster extractions.

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Quick check on the data types of the variables in the dataframe
df_venues_count.dtypes.to_frame(name='Data Type')
# Out:
#                Data Type
# Category
# Bus Stop        float64
# Food            float64
# Metro Station   float64
# Shop & Service  float64

# %%
# Since all data types are numeric, we could generate summary statistics for quick analysis
df_venues_count.describe()
# Out:
# Category   Bus Stop       Food  Metro Station  Shop & Service
# count     12.000000  12.000000  12.000000      12.000000
# mean      2.916667   12.166667  0.416667       5.583333
# std       1.975225   9.379216   0.514929       4.813963
# min       0.000000   1.000000   0.000000       0.000000
# 25%       1.000000   5.000000   0.000000       2.000000
# 50%       3.000000   9.500000   0.000000       4.000000
# 75%       4.000000   18.000000  1.000000       7.750000
# max       6.000000   30.000000  1.000000       14.000000

# %%
# Plotting the venues to analyse visually (Metro Station not plotted since the range is small)
f, axes = plt.subplots(2, 2, figsize=(10, 10))
sns.distplot(df_venues_count['Bus Stop'] , color="darkblue", ax=axes[0, 0], kde=False)
sns.distplot(df_venues_count['Food'] , color="gold", ax=axes[0, 1], kde=False)
sns.distplot(df_venues_count['Shop & Service'] , color="grey", ax=axes[1, 0], kde=False)

# %%
# To determine the correlation of the venues
df_venues_count.corr()
# Out:
# Category        Bus Stop      Food  Metro Station  Shop & Service
# Category
# Bus Stop        1.000000  0.231451 -0.141519       0.148987
# Food            0.231451  1.000000 -0.109802       0.621816
# Metro Station  -0.141519 -0.109802  1.000000      -0.473705
# Shop & Service  0.148987  0.621816 -0.473705       1.000000

# %% [markdown]
# It seems that only 'Food' and 'Shop & Service' categories are correlated. We will next proceed to find out P-Value of the variables
#
# By convention, when the p-value is:
#
# < 0.001 there is strong evidence that the correlation is significant,
# < 0.05; there is moderate evidence that the correlation is significant,
# < 0.1; there is weak evidence that the correlation is significant, and
# is > 0.1; there is no evidence that the correlation is significant.

# %%
from scipy import stats

p_value_data = []
for left in df_venues_count.columns:
    p_values = [left]
    for right in df_venues_count.columns:        
        pearson_coef, p_value = stats.pearsonr(df_venues_count[left], df_venues_count[right])
        if(p_value < 0.001):
            p_values.append('Strong')
        elif(p_value < 0.05):
            p_values.append('Moderate')
        elif(p_value < 0.1):
            p_values.append('Weak')
        else:
            p_values.append('No')            
    p_value_data.append(p_values)

# %%
df_p_values = pd.DataFrame(p_value_data, columns=['Category'] + df_venues_count.columns.tolist())

# %%
df_p_values
# Out:
#          Category Bus Stop      Food Metro Station Shop & Service
# 0  Bus Stop        Strong   No        No            No
# 1  Food            No       Strong    No            Moderate
# 2  Metro Station   No       No        Strong        No
# 3  Shop & Service  No       Moderate  No            Strong

# %% [markdown]
# The correlation between 'Food' and 'Shop & Service' are statistically significant, and the coefficient of > 0.5 shows that the relationship is positive. We would be considering locations with higher number of 'Food' and 'Shop & Service' nearby.

# %% [markdown]
# ### 3.3 Data Visualisation

# %%
# !conda install -c conda-forge folium=0.5 --yes
import folium

print('Folium installed and imported!')
# Out:
# Collecting package metadata: ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\dell\Anaconda3
#
#   added / updated specs:
#     - folium=0.5
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boost-cpp-1.68.0           |    h6a4c333_1000        31.1 MB  conda-forge
#     certifi-2019.3.9           |           py37_0         149 KB  conda-forge
#     libkml-1.3.0               |    h4fd0f3b_1009        54.7 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        86.0 MB
#
# The following packages will be UPDATED:
#
#   conda                      pkgs/main::conda-4.6.14-py37_0 --> conda-forge::conda-4.7.5-py37_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi                                         pkgs/main --> conda-forge
#
# The following packages will be DOWNGRADED:
#
#   boost-cpp                               1.70.0-h6a4c333_0 --> 1.68.0-h6a4c333_1000
#   libkml                                1.3.0-h4ece8bf_1010 --> 1.3.0-h4fd0f3b_1009
#
#
#
# Downloading and Extracting Packages
#
# boost-cpp-1.68.0     | 31.1 MB   |            |   0%
# boost-cpp-1.68.0     | 31.1 MB   |            |   0%
# boost-cpp-1.68.0     | 31.1 MB   | 1          |   1%
# boost-cpp-1.68.0     | 31.1 MB   | 2          |   2%
# boost-cpp-1.68.0     | 31.1 MB   | 3          |   3%
# boost-cpp-1.68.0     | 31.1 MB   | 4          |   4%
# boost-cpp-1.68.0     | 31.1 MB   | 5          |   5%
# boost-cpp-1.68.0     | 31.1 MB   | 5          |   6%
# boost-cpp-1.68.0     | 31.1 MB   | 6          |   7%
# boost-cpp-1.68.0     | 31.1 MB   | 7          |   8%
# boost-cpp-1.68.0     | 31.1 MB   | 9          |   9%
# boost-cpp-1.68.0     | 31.1 MB   | #          |  10%
# boost-cpp-1.68.0     | 31.1 MB   | #1         |  11%
# boost-cpp-1.68.0     | 31.1 MB   | #2         |  12%
# boost-cpp-1.68.0     | 31.1 MB   | #2         |  13%
# boost-cpp-1.68.0     | 31.1 MB   | #3         |  14%
# boost-cpp-1.68.0     | 31.1 MB   | #4         |  15%
# boost-cpp-1.68.0     | 31.1 MB   | #5         |  16%
# boost-cpp-1.68.0     | 31.1 MB   | #6         |  17%
# boost-cpp-1.68.0     | 31.1 MB   | #7         |  17%
# boost-cpp-1.68.0     | 31.1 MB   | #8         |  18%
# boost-cpp-1.68.0     | 31.1 MB   | #8         |  19%
# boost-cpp-1.68.0     | 31.1 MB   | #9         |  19%
# boost-cpp-1.68.0     | 31.1 MB   | ##         |  20%
# boost-cpp-1.68.0     | 31.1 MB   | ##1        |  21%
# boost-cpp-1.68.0     | 31.1 MB   | ##2        |  22%
# boost-cpp-1.68.0     | 31.1 MB   | ##3        |  24%
# boost-cpp-1.68.0     | 31.1 MB   | ##4        |  25%
# boost-cpp-1.68.0     | 31.1 MB   | ##5        |  26%
# boost-cpp-1.68.0     | 31.1 MB   | ##6        |  27%
# boost-cpp-1.68.0     | 31.1 MB   | ##7        |  28%
# boost-cpp-1.68.0     | 31.1 MB   | ##8        |  28%
# boost-cpp-1.68.0     | 31.1 MB   | ##9        |  29%
# boost-cpp-1.68.0     | 31.1 MB   | ###        |  30%
# boost-cpp-1.68.0     | 31.1 MB   | ###1       |  31%
# boost-cpp-1.68.0     | 31.1 MB   | ###2       |  32%
# boost-cpp-1.68.0     | 31.1 MB   | ###2       |  33%
# boost-cpp-1.68.0     | 31.1 MB   | ###3       |  34%
# boost-cpp-1.68.0     | 31.1 MB   | ###4       |  34%
# boost-cpp-1.68.0     | 31.1 MB   | ###4       |  35%
# boost-cpp-1.68.0     | 31.1 MB   | ###5       |  36%
# boost-cpp-1.68.0     | 31.1 MB   | ###6       |  37%
# boost-cpp-1.68.0     | 31.1 MB   | ###7       |  37%
# boost-cpp-1.68.0     | 31.1 MB   | ###8       |  38%
# boost-cpp-1.68.0     | 31.1 MB   | ###9       |  40%
# boost-cpp-1.68.0     | 31.1 MB   | ####       |  41%
# boost-cpp-1.68.0     | 31.1 MB   | ####1      |  42%
# boost-cpp-1.68.0     | 31.1 MB   | ####3      |  43%
# boost-cpp-1.68.0     | 31.1 MB   | ####4      |  44%
# boost-cpp-1.68.0     | 31.1 MB   | ####5      |  45%
# boost-cpp-1.68.0     | 31.1 MB   | ####6      |  47%
# boost-cpp-1.68.0     | 31.1 MB   | ####7      |  48%
# boost-cpp-1.68.0     | 31.1 MB   | ####8      |  49%
# boost-cpp-1.68.0     | 31.1 MB   | #####      |  50%
# boost-cpp-1.68.0     | 31.1 MB   | #####1     |  52%
# boost-cpp-1.68.0     | 31.1 MB   | #####2     |  53%
# boost-cpp-1.68.0     | 31.1 MB   | #####3     |  54%
# boost-cpp-1.68.0     | 31.1 MB   | #####5     |  55%
# boost-cpp-1.68.0     | 31.1 MB   | #####6     |  56%
# boost-cpp-1.68.0     | 31.1 MB   | #####7     |  57%
# boost-cpp-1.68.0     | 31.1 MB   | #####8     |  59%
# boost-cpp-1.68.0     | 31.1 MB   | #####9     |  60%
# boost-cpp-1.68.0     | 31.1 MB   | ######1    |  61%
# boost-cpp-1.68.0     | 31.1 MB   | ######2    |  62%
# boost-cpp-1.68.0     | 31.1 MB   | ######3    |  64%
# boost-cpp-1.68.0     | 31.1 MB   | ######4    |  65%
# boost-cpp-1.68.0     | 31.1 MB   | ######5    |  66%
# boost-cpp-1.68.0     | 31.1 MB   | ######7    |  67%
# boost-cpp-1.68.0     | 31.1 MB   | ######8    |  68%
# boost-cpp-1.68.0     | 31.1 MB   | ######9    |  69%
# boost-cpp-1.68.0     | 31.1 MB   | #######    |  71%
# boost-cpp-1.68.0     | 31.1 MB   | #######1   |  72%
# boost-cpp-1.68.0     | 31.1 MB   | #######2   |  73%
# boost-cpp-1.68.0     | 31.1 MB   | #######4   |  74%
# boost-cpp-1.68.0     | 31.1 MB   | #######5   |  75%
# boost-cpp-1.68.0     | 31.1 MB   | #######6   |  76%
# boost-cpp-1.68.0     | 31.1 MB   | #######6   |  77%
# boost-cpp-1.68.0     | 31.1 MB   | #######7   |  77%
# boost-cpp-1.68.0     | 31.1 MB   | #######7   |  78%
# boost-cpp-1.68.0     | 31.1 MB   | #######7   |  78%
# boost-cpp-1.68.0     | 31.1 MB   | #######8   |  78%
# boost-cpp-1.68.0     | 31.1 MB   | #######8   |  78%
# boost-cpp-1.68.0     | 31.1 MB   | #######8   |  79%
# boost-cpp-1.68.0     | 31.1 MB   | #######8   |  79%
# boost-cpp-1.68.0     | 31.1 MB   | #######9   |  79%
# boost-cpp-1.68.0     | 31.1 MB   | #######9   |  79%
# boost-cpp-1.68.0     | 31.1 MB   | #######9   |  79%
# boost-cpp-1.68.0     | 31.1 MB   | #######9   |  80%
# boost-cpp-1.68.0     | 31.1 MB   | #######9   |  80%
# boost-cpp-1.68.0     | 31.1 MB   | ########   |  80%
# boost-cpp-1.68.0     | 31.1 MB   | ########   |  80%
# boost-cpp-1.68.0     | 31.1 MB   | ########   |  81%
# boost-cpp-1.68.0     | 31.1 MB   | ########   |  81%
# boost-cpp-1.68.0     | 31.1 MB   | ########   |  81%
# boost-cpp-1.68.0     | 31.1 MB   | ########1  |  81%
# boost-cpp-1.68.0     | 31.1 MB   | ########1  |  81%
# boost-cpp-1.68.0     | 31.1 MB   | ########1  |  82%
# boost-cpp-1.68.0     | 31.1 MB   | ########1  |  82%
# boost-cpp-1.68.0     | 31.1 MB   | ########2  |  82%
# boost-cpp-1.68.0     | 31.1 MB   | ########2  |  82%
# boost-cpp-1.68.0     | 31.1 MB   | ########2  |  82%
# boost-cpp-1.68.0     | 31.1 MB   | ########2  |  83%
# boost-cpp-1.68.0     | 31.1 MB   | ########2  |  83%
# boost-cpp-1.68.0     | 31.1 MB   | ########3  |  83%
# boost-cpp-1.68.0     | 31.1 MB   | ########3  |  83%
# boost-cpp-1.68.0     | 31.1 MB   | ########3  |  83%
# boost-cpp-1.68.0     | 31.1 MB   | ########3  |  84%
# boost-cpp-1.68.0     | 31.1 MB   | ########3  |  84%
# boost-cpp-1.68.0     | 31.1 MB   | ########4  |  84%
# boost-cpp-1.68.0     | 31.1 MB   | ########4  |  84%
# boost-cpp-1.68.0     | 31.1 MB   | ########4  |  84%
# boost-cpp-1.68.0     | 31.1 MB   | ########4  |  85%
# boost-cpp-1.68.0     | 31.1 MB   | ########4  |  85%
# boost-cpp-1.68.0     | 31.1 MB   | ########4  |  85%
# boost-cpp-1.68.0     | 31.1 MB   | ########5  |  85%
# boost-cpp-1.68.0     | 31.1 MB   | ########5  |  85%
# boost-cpp-1.68.0     | 31.1 MB   | ########5  |  85%
# boost-cpp-1.68.0     | 31.1 MB   | ########5  |  86%
# boost-cpp-1.68.0     | 31.1 MB   | ########5  |  86%
# boost-cpp-1.68.0     | 31.1 MB   | ########6  |  86%
# boost-cpp-1.68.0     | 31.1 MB   | ########6  |  86%
# boost-cpp-1.68.0     | 31.1 MB   | ########6  |  86%
# boost-cpp-1.68.0     | 31.1 MB   | ########6  |  87%
# boost-cpp-1.68.0     | 31.1 MB   | ########7  |  87%
# boost-cpp-1.68.0     | 31.1 MB   | ########7  |  87%
# boost-cpp-1.68.0     | 31.1 MB   | ########7  |  87%
# boost-cpp-1.68.0     | 31.1 MB   | ########7  |  88%
# boost-cpp-1.68.0     | 31.1 MB   | ########7  |  88%
# boost-cpp-1.68.0     | 31.1 MB   | ########7  |  88%
# boost-cpp-1.68.0     | 31.1 MB   | ########8  |  88%
# boost-cpp-1.68.0     | 31.1 MB   | ########8  |  88%
# boost-cpp-1.68.0     | 31.1 MB   | ########8  |  88%
# boost-cpp-1.68.0     | 31.1 MB   | ########8  |  89%
# boost-cpp-1.68.0     | 31.1 MB   | ########8  |  89%
# boost-cpp-1.68.0     | 31.1 MB   | ########9  |  89%
# boost-cpp-1.68.0     | 31.1 MB   | ########9  |  89%
# boost-cpp-1.68.0     | 31.1 MB   | ########9  |  89%
# boost-cpp-1.68.0     | 31.1 MB   | ########9  |  90%
# boost-cpp-1.68.0     | 31.1 MB   | ########9  |  90%
# boost-cpp-1.68.0     | 31.1 MB   | #########  |  90%
# boost-cpp-1.68.0     | 31.1 MB   | #########  |  90%
# boost-cpp-1.68.0     | 31.1 MB   | #########  |  91%
# boost-cpp-1.68.0     | 31.1 MB   | #########  |  91%
# boost-cpp-1.68.0     | 31.1 MB   | #########1 |  91%
# boost-cpp-1.68.0     | 31.1 MB   | #########1 |  91%
# boost-cpp-1.68.0     | 31.1 MB   | #########1 |  91%
# boost-cpp-1.68.0     | 31.1 MB   | #########1 |  92%
# boost-cpp-1.68.0     | 31.1 MB   | #########1 |  92%
# boost-cpp-1.68.0     | 31.1 MB   | #########2 |  92%
# boost-cpp-1.68.0     | 31.1 MB   | #########2 |  92%
# boost-cpp-1.68.0     | 31.1 MB   | #########2 |  92%
# boost-cpp-1.68.0     | 31.1 MB   | #########2 |  93%
# boost-cpp-1.68.0     | 31.1 MB   | #########2 |  93%
# boost-cpp-1.68.0     | 31.1 MB   | #########2 |  93%
# boost-cpp-1.68.0     | 31.1 MB   | #########3 |  93%
# boost-cpp-1.68.0     | 31.1 MB   | #########3 |  93%
# boost-cpp-1.68.0     | 31.1 MB   | #########3 |  93%
# boost-cpp-1.68.0     | 31.1 MB   | #########3 |  94%
# boost-cpp-1.68.0     | 31.1 MB   | #########3 |  94%
# boost-cpp-1.68.0     | 31.1 MB   | #########4 |  94%
# boost-cpp-1.68.0     | 31.1 MB   | #########4 |  94%
# boost-cpp-1.68.0     | 31.1 MB   | #########4 |  95%
# boost-cpp-1.68.0     | 31.1 MB   | #########4 |  95%
# boost-cpp-1.68.0     | 31.1 MB   | #########5 |  95%
# boost-cpp-1.68.0     | 31.1 MB   | #########5 |  95%
# boost-cpp-1.68.0     | 31.1 MB   | #########5 |  95%
# boost-cpp-1.68.0     | 31.1 MB   | #########5 |  96%
# boost-cpp-1.68.0     | 31.1 MB   | #########5 |  96%
# boost-cpp-1.68.0     | 31.1 MB   | #########6 |  96%
# boost-cpp-1.68.0     | 31.1 MB   | #########6 |  96%
# boost-cpp-1.68.0     | 31.1 MB   | #########6 |  96%
# boost-cpp-1.68.0     | 31.1 MB   | #########6 |  97%
# boost-cpp-1.68.0     | 31.1 MB   | #########6 |  97%
# boost-cpp-1.68.0     | 31.1 MB   | #########7 |  97%
# boost-cpp-1.68.0     | 31.1 MB   | #########7 |  97%
# boost-cpp-1.68.0     | 31.1 MB   | #########7 |  98%
# boost-cpp-1.68.0     | 31.1 MB   | #########7 |  98%
# boost-cpp-1.68.0     | 31.1 MB   | #########7 |  98%
# boost-cpp-1.68.0     | 31.1 MB   | #########8 |  98%
# boost-cpp-1.68.0     | 31.1 MB   | #########8 |  98%
# boost-cpp-1.68.0     | 31.1 MB   | #########8 |  98%
# boost-cpp-1.68.0     | 31.1 MB   | #########8 |  99%
# boost-cpp-1.68.0     | 31.1 MB   | #########8 |  99%
# boost-cpp-1.68.0     | 31.1 MB   | #########8 |  99%
# boost-cpp-1.68.0     | 31.1 MB   | #########9 |  99%
# boost-cpp-1.68.0     | 31.1 MB   | #########9 |  99%
# boost-cpp-1.68.0     | 31.1 MB   | #########9 |  99%
# boost-cpp-1.68.0     | 31.1 MB   | #########9 | 100%
# boost-cpp-1.68.0     | 31.1 MB   | #########9 | 100%
# boost-cpp-1.68.0     | 31.1 MB   | #########9 | 100%
# boost-cpp-1.68.0     | 31.1 MB   | #########9 | 100%
# boost-cpp-1.68.0     | 31.1 MB   | #########9 | 100%
# boost-cpp-1.68.0     | 31.1 MB   | ########## | 100%
#
# libkml-1.3.0         | 54.7 MB   |            |   0%
# libkml-1.3.0         | 54.7 MB   |            |   0%
# libkml-1.3.0         | 54.7 MB   |            |   1%
# libkml-1.3.0         | 54.7 MB   | 1          |   1%
# libkml-1.3.0         | 54.7 MB   | 2          |   2%
# libkml-1.3.0         | 54.7 MB   | 2          |   3%
# libkml-1.3.0         | 54.7 MB   | 3          |   3%
# libkml-1.3.0         | 54.7 MB   | 3          |   4%
# libkml-1.3.0         | 54.7 MB   | 4          |   5%
# libkml-1.3.0         | 54.7 MB   | 5          |   5%
# libkml-1.3.0         | 54.7 MB   | 6          |   6%
# libkml-1.3.0         | 54.7 MB   | 6          |   7%
# libkml-1.3.0         | 54.7 MB   | 7          |   7%
# libkml-1.3.0         | 54.7 MB   | 7          |   8%
# libkml-1.3.0         | 54.7 MB   | 8          |   9%
# libkml-1.3.0         | 54.7 MB   | 9          |   9%
# libkml-1.3.0         | 54.7 MB   | #          |  10%
# libkml-1.3.0         | 54.7 MB   | #          |  11%
# libkml-1.3.0         | 54.7 MB   | #1         |  11%
# libkml-1.3.0         | 54.7 MB   | #2         |  12%
# libkml-1.3.0         | 54.7 MB   | #2         |  13%
# libkml-1.3.0         | 54.7 MB   | #3         |  14%
# libkml-1.3.0         | 54.7 MB   | #4         |  14%
# libkml-1.3.0         | 54.7 MB   | #4         |  15%
# libkml-1.3.0         | 54.7 MB   | #5         |  16%
# libkml-1.3.0         | 54.7 MB   | #6         |  16%
# libkml-1.3.0         | 54.7 MB   | #7         |  17%
# libkml-1.3.0         | 54.7 MB   | #7         |  18%
# libkml-1.3.0         | 54.7 MB   | #8         |  18%
# libkml-1.3.0         | 54.7 MB   | #9         |  19%
# libkml-1.3.0         | 54.7 MB   | #9         |  20%
# libkml-1.3.0         | 54.7 MB   | ##         |  21%
# libkml-1.3.0         | 54.7 MB   | ##1        |  21%
# libkml-1.3.0         | 54.7 MB   | ##1        |  22%
# libkml-1.3.0         | 54.7 MB   | ##2        |  23%
# libkml-1.3.0         | 54.7 MB   | ##3        |  23%
# libkml-1.3.0         | 54.7 MB   | ##4        |  24%
# libkml-1.3.0         | 54.7 MB   | ##4        |  25%
# libkml-1.3.0         | 54.7 MB   | ##5        |  26%
# libkml-1.3.0         | 54.7 MB   | ##6        |  26%
# libkml-1.3.0         | 54.7 MB   | ##6        |  27%
# libkml-1.3.0         | 54.7 MB   | ##7        |  28%
# libkml-1.3.0         | 54.7 MB   | ##8        |  28%
# libkml-1.3.0         | 54.7 MB   | ##8        |  29%
# libkml-1.3.0         | 54.7 MB   | ##9        |  30%
# libkml-1.3.0         | 54.7 MB   | ###        |  30%
# libkml-1.3.0         | 54.7 MB   | ###        |  31%
# libkml-1.3.0         | 54.7 MB   | ###1       |  32%
# libkml-1.3.0         | 54.7 MB   | ###2       |  32%
# libkml-1.3.0         | 54.7 MB   | ###3       |  33%
# libkml-1.3.0         | 54.7 MB   | ###3       |  34%
# libkml-1.3.0         | 54.7 MB   | ###4       |  34%
# libkml-1.3.0         | 54.7 MB   | ###5       |  35%
# libkml-1.3.0         | 54.7 MB   | ###5       |  36%
# libkml-1.3.0         | 54.7 MB   | ###6       |  36%
# libkml-1.3.0         | 54.7 MB   | ###7       |  37%
# libkml-1.3.0         | 54.7 MB   | ###7       |  38%
# libkml-1.3.0         | 54.7 MB   | ###8       |  38%
# libkml-1.3.0         | 54.7 MB   | ###9       |  39%
# libkml-1.3.0         | 54.7 MB   | ###9       |  40%
# libkml-1.3.0         | 54.7 MB   | ####       |  40%
# libkml-1.3.0         | 54.7 MB   | ####1      |  41%
# libkml-1.3.0         | 54.7 MB   | ####1      |  42%
# libkml-1.3.0         | 54.7 MB   | ####2      |  43%
# libkml-1.3.0         | 54.7 MB   | ####3      |  43%
# libkml-1.3.0         | 54.7 MB   | ####3      |  44%
# libkml-1.3.0         | 54.7 MB   | ####4      |  45%
# libkml-1.3.0         | 54.7 MB   | ####5      |  45%
# libkml-1.3.0         | 54.7 MB   | ####5      |  46%
# libkml-1.3.0         | 54.7 MB   | ####6      |  47%
# libkml-1.3.0         | 54.7 MB   | ####7      |  47%
# libkml-1.3.0         | 54.7 MB   | ####8      |  48%
# libkml-1.3.0         | 54.7 MB   | ####8      |  49%
# libkml-1.3.0         | 54.7 MB   | ####9      |  49%
# libkml-1.3.0         | 54.7 MB   | #####      |  50%
# libkml-1.3.0         | 54.7 MB   | #####      |  51%
# libkml-1.3.0         | 54.7 MB   | #####1     |  51%
# libkml-1.3.0         | 54.7 MB   | #####2     |  52%
# libkml-1.3.0         | 54.7 MB   | #####2     |  53%
# libkml-1.3.0         | 54.7 MB   | #####3     |  54%
# libkml-1.3.0         | 54.7 MB   | #####4     |  54%
# libkml-1.3.0         | 54.7 MB   | #####4     |  55%
# libkml-1.3.0         | 54.7 MB   | #####5     |  56%
# libkml-1.3.0         | 54.7 MB   | #####6     |  56%
# libkml-1.3.0         | 54.7 MB   | #####6     |  57%
# libkml-1.3.0         | 54.7 MB   | #####7     |  58%
# libkml-1.3.0         | 54.7 MB   | #####8     |  58%
# libkml-1.3.0         | 54.7 MB   | #####9     |  59%
# libkml-1.3.0         | 54.7 MB   | #####9     |  60%
# libkml-1.3.0         | 54.7 MB   | ######     |  60%
# libkml-1.3.0         | 54.7 MB   | ######1    |  61%
# libkml-1.3.0         | 54.7 MB   | ######1    |  62%
# libkml-1.3.0         | 54.7 MB   | ######2    |  63%
# libkml-1.3.0         | 54.7 MB   | ######3    |  63%
# libkml-1.3.0         | 54.7 MB   | ######4    |  64%
# libkml-1.3.0         | 54.7 MB   | ######4    |  65%
# libkml-1.3.0         | 54.7 MB   | ######5    |  66%
# libkml-1.3.0         | 54.7 MB   | ######6    |  66%
# libkml-1.3.0         | 54.7 MB   | ######7    |  67%
# libkml-1.3.0         | 54.7 MB   | ######7    |  68%
# libkml-1.3.0         | 54.7 MB   | ######8    |  68%
# libkml-1.3.0         | 54.7 MB   | ######9    |  69%
# libkml-1.3.0         | 54.7 MB   | ######9    |  70%
# libkml-1.3.0         | 54.7 MB   | #######    |  70%
# libkml-1.3.0         | 54.7 MB   | #######1   |  71%
# libkml-1.3.0         | 54.7 MB   | #######1   |  72%
# libkml-1.3.0         | 54.7 MB   | #######2   |  73%
# libkml-1.3.0         | 54.7 MB   | #######3   |  73%
# libkml-1.3.0         | 54.7 MB   | #######3   |  74%
# libkml-1.3.0         | 54.7 MB   | #######4   |  75%
# libkml-1.3.0         | 54.7 MB   | #######5   |  75%
# libkml-1.3.0         | 54.7 MB   | #######5   |  76%
# libkml-1.3.0         | 54.7 MB   | #######6   |  76%
# libkml-1.3.0         | 54.7 MB   | #######6   |  76%
# libkml-1.3.0         | 54.7 MB   | #######6   |  77%
# libkml-1.3.0         | 54.7 MB   | #######6   |  77%
# libkml-1.3.0         | 54.7 MB   | #######7   |  77%
# libkml-1.3.0         | 54.7 MB   | #######7   |  77%
# libkml-1.3.0         | 54.7 MB   | #######7   |  77%
# libkml-1.3.0         | 54.7 MB   | #######7   |  78%
# libkml-1.3.0         | 54.7 MB   | #######7   |  78%
# libkml-1.3.0         | 54.7 MB   | #######7   |  78%
# libkml-1.3.0         | 54.7 MB   | #######8   |  78%
# libkml-1.3.0         | 54.7 MB   | #######8   |  78%
# libkml-1.3.0         | 54.7 MB   | #######8   |  79%
# libkml-1.3.0         | 54.7 MB   | #######8   |  79%
# libkml-1.3.0         | 54.7 MB   | #######8   |  79%
# libkml-1.3.0         | 54.7 MB   | #######8   |  79%
# libkml-1.3.0         | 54.7 MB   | #######9   |  79%
# libkml-1.3.0         | 54.7 MB   | #######9   |  79%
# libkml-1.3.0         | 54.7 MB   | #######9   |  79%
# libkml-1.3.0         | 54.7 MB   | #######9   |  80%
# libkml-1.3.0         | 54.7 MB   | #######9   |  80%
# libkml-1.3.0         | 54.7 MB   | #######9   |  80%
# libkml-1.3.0         | 54.7 MB   | #######9   |  80%
# libkml-1.3.0         | 54.7 MB   | ########   |  80%
# libkml-1.3.0         | 54.7 MB   | ########   |  80%
# libkml-1.3.0         | 54.7 MB   | ########   |  80%
# libkml-1.3.0         | 54.7 MB   | ########   |  81%
# libkml-1.3.0         | 54.7 MB   | ########   |  81%
# libkml-1.3.0         | 54.7 MB   | ########   |  81%
# libkml-1.3.0         | 54.7 MB   | ########1  |  81%
# libkml-1.3.0         | 54.7 MB   | ########1  |  81%
# libkml-1.3.0         | 54.7 MB   | ########1  |  81%
# libkml-1.3.0         | 54.7 MB   | ########1  |  81%
# libkml-1.3.0         | 54.7 MB   | ########1  |  82%
# libkml-1.3.0         | 54.7 MB   | ########1  |  82%
# libkml-1.3.0         | 54.7 MB   | ########1  |  82%
# libkml-1.3.0         | 54.7 MB   | ########2  |  82%
# libkml-1.3.0         | 54.7 MB   | ########2  |  82%
# libkml-1.3.0         | 54.7 MB   | ########2  |  82%
# libkml-1.3.0         | 54.7 MB   | ########2  |  83%
# libkml-1.3.0         | 54.7 MB   | ########2  |  83%
# libkml-1.3.0         | 54.7 MB   | ########2  |  83%
# libkml-1.3.0         | 54.7 MB   | ########2  |  83%
# libkml-1.3.0         | 54.7 MB   | ########3  |  83%
# libkml-1.3.0         | 54.7 MB   | ########3  |  83%
# libkml-1.3.0         | 54.7 MB   | ########3  |  83%
# libkml-1.3.0         | 54.7 MB   | ########3  |  84%
# libkml-1.3.0         | 54.7 MB   | ########3  |  84%
# libkml-1.3.0         | 54.7 MB   | ########3  |  84%
# libkml-1.3.0         | 54.7 MB   | ########4  |  84%
# libkml-1.3.0         | 54.7 MB   | ########4  |  84%
# libkml-1.3.0         | 54.7 MB   | ########4  |  84%
# libkml-1.3.0         | 54.7 MB   | ########4  |  85%
# libkml-1.3.0         | 54.7 MB   | ########4  |  85%
# libkml-1.3.0         | 54.7 MB   | ########4  |  85%
# libkml-1.3.0         | 54.7 MB   | ########5  |  85%
# libkml-1.3.0         | 54.7 MB   | ########5  |  85%
# libkml-1.3.0         | 54.7 MB   | ########5  |  85%
# libkml-1.3.0         | 54.7 MB   | ########5  |  85%
# libkml-1.3.0         | 54.7 MB   | ########5  |  86%
# libkml-1.3.0         | 54.7 MB   | ########5  |  86%
# libkml-1.3.0         | 54.7 MB   | ########5  |  86%
# libkml-1.3.0         | 54.7 MB   | ########6  |  86%
# libkml-1.3.0         | 54.7 MB   | ########6  |  86%
# libkml-1.3.0         | 54.7 MB   | ########6  |  86%
# libkml-1.3.0         | 54.7 MB   | ########6  |  86%
# libkml-1.3.0         | 54.7 MB   | ########6  |  87%
# libkml-1.3.0         | 54.7 MB   | ########6  |  87%
# libkml-1.3.0         | 54.7 MB   | ########6  |  87%
# libkml-1.3.0         | 54.7 MB   | ########7  |  87%
# libkml-1.3.0         | 54.7 MB   | ########7  |  87%
# libkml-1.3.0         | 54.7 MB   | ########7  |  87%
# libkml-1.3.0         | 54.7 MB   | ########7  |  87%
# libkml-1.3.0         | 54.7 MB   | ########7  |  88%
# libkml-1.3.0         | 54.7 MB   | ########7  |  88%
# libkml-1.3.0         | 54.7 MB   | ########7  |  88%
# libkml-1.3.0         | 54.7 MB   | ########8  |  88%
# libkml-1.3.0         | 54.7 MB   | ########8  |  88%
# libkml-1.3.0         | 54.7 MB   | ########8  |  88%
# libkml-1.3.0         | 54.7 MB   | ########8  |  89%
# libkml-1.3.0         | 54.7 MB   | ########8  |  89%
# libkml-1.3.0         | 54.7 MB   | ########8  |  89%
# libkml-1.3.0         | 54.7 MB   | ########8  |  89%
# libkml-1.3.0         | 54.7 MB   | ########9  |  89%
# libkml-1.3.0         | 54.7 MB   | ########9  |  89%
# libkml-1.3.0         | 54.7 MB   | ########9  |  89%
# libkml-1.3.0         | 54.7 MB   | ########9  |  90%
# libkml-1.3.0         | 54.7 MB   | ########9  |  90%
# libkml-1.3.0         | 54.7 MB   | ########9  |  90%
# libkml-1.3.0         | 54.7 MB   | ########9  |  90%
# libkml-1.3.0         | 54.7 MB   | #########  |  90%
# libkml-1.3.0         | 54.7 MB   | #########  |  90%
# libkml-1.3.0         | 54.7 MB   | #########  |  90%
# libkml-1.3.0         | 54.7 MB   | #########  |  91%
# libkml-1.3.0         | 54.7 MB   | #########  |  91%
# libkml-1.3.0         | 54.7 MB   | #########  |  91%
# libkml-1.3.0         | 54.7 MB   | #########1 |  91%
# libkml-1.3.0         | 54.7 MB   | #########1 |  91%
# libkml-1.3.0         | 54.7 MB   | #########1 |  91%
# libkml-1.3.0         | 54.7 MB   | #########1 |  92%
# libkml-1.3.0         | 54.7 MB   | #########1 |  92%
# libkml-1.3.0         | 54.7 MB   | #########1 |  92%
# libkml-1.3.0         | 54.7 MB   | #########1 |  92%
# libkml-1.3.0         | 54.7 MB   | #########2 |  92%
# libkml-1.3.0         | 54.7 MB   | #########2 |  92%
# libkml-1.3.0         | 54.7 MB   | #########2 |  92%
# libkml-1.3.0         | 54.7 MB   | #########2 |  93%
# libkml-1.3.0         | 54.7 MB   | #########2 |  93%
# libkml-1.3.0         | 54.7 MB   | #########2 |  93%
# libkml-1.3.0         | 54.7 MB   | #########3 |  93%
# libkml-1.3.0         | 54.7 MB   | #########3 |  93%
# libkml-1.3.0         | 54.7 MB   | #########3 |  93%
# libkml-1.3.0         | 54.7 MB   | #########3 |  94%
# libkml-1.3.0         | 54.7 MB   | #########3 |  94%
# libkml-1.3.0         | 54.7 MB   | #########3 |  94%
# libkml-1.3.0         | 54.7 MB   | #########3 |  94%
# libkml-1.3.0         | 54.7 MB   | #########4 |  94%
# libkml-1.3.0         | 54.7 MB   | #########4 |  94%
# libkml-1.3.0         | 54.7 MB   | #########4 |  94%
# libkml-1.3.0         | 54.7 MB   | #########4 |  95%
# libkml-1.3.0         | 54.7 MB   | #########4 |  95%
# libkml-1.3.0         | 54.7 MB   | #########4 |  95%
# libkml-1.3.0         | 54.7 MB   | #########5 |  95%
# libkml-1.3.0         | 54.7 MB   | #########5 |  95%
# libkml-1.3.0         | 54.7 MB   | #########5 |  95%
# libkml-1.3.0         | 54.7 MB   | #########5 |  96%
# libkml-1.3.0         | 54.7 MB   | #########5 |  96%
# libkml-1.3.0         | 54.7 MB   | #########5 |  96%
# libkml-1.3.0         | 54.7 MB   | #########5 |  96%
# libkml-1.3.0         | 54.7 MB   | #########6 |  96%
# libkml-1.3.0         | 54.7 MB   | #########6 |  96%
# libkml-1.3.0         | 54.7 MB   | #########6 |  96%
# libkml-1.3.0         | 54.7 MB   | #########6 |  97%
# libkml-1.3.0         | 54.7 MB   | #########6 |  97%
# libkml-1.3.0         | 54.7 MB   | #########6 |  97%
# libkml-1.3.0         | 54.7 MB   | #########7 |  97%
# libkml-1.3.0         | 54.7 MB   | #########7 |  97%
# libkml-1.3.0         | 54.7 MB   | #########7 |  97%
# libkml-1.3.0         | 54.7 MB   | #########7 |  98%
# libkml-1.3.0         | 54.7 MB   | #########7 |  98%
# libkml-1.3.0         | 54.7 MB   | #########7 |  98%
# libkml-1.3.0         | 54.7 MB   | #########8 |  98%
# libkml-1.3.0         | 54.7 MB   | #########8 |  98%
# libkml-1.3.0         | 54.7 MB   | #########8 |  98%
# libkml-1.3.0         | 54.7 MB   | #########8 |  98%
# libkml-1.3.0         | 54.7 MB   | #########8 |  99%
# libkml-1.3.0         | 54.7 MB   | #########8 |  99%
# libkml-1.3.0         | 54.7 MB   | #########8 |  99%
# libkml-1.3.0         | 54.7 MB   | #########9 |  99%
# libkml-1.3.0         | 54.7 MB   | #########9 |  99%
# libkml-1.3.0         | 54.7 MB   | #########9 |  99%
# libkml-1.3.0         | 54.7 MB   | #########9 | 100%
# libkml-1.3.0         | 54.7 MB   | #########9 | 100%
# libkml-1.3.0         | 54.7 MB   | #########9 | 100%
# libkml-1.3.0         | 54.7 MB   | ########## | 100%
#
# certifi-2019.3.9     | 149 KB    |            |   0%
# certifi-2019.3.9     | 149 KB    | #######5   |  75%
# certifi-2019.3.9     | 149 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.6.14
#   latest version: 4.7.5
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
# Folium installed and imported!

# %%
# Showing the locations on Singapore Map
sg_map = folium.Map(location=[1.38, 103.8], zoom_start=12,tiles='Stamen Toner')

outlets_fg = folium.FeatureGroup()
shortlisted_fg = folium.FeatureGroup()

for(location, address, latitude, longitude) in df_shortlisted_locations.itertuples(index=False):
    shortlisted_fg.add_child(
        folium.features.CircleMarker(
            location=(latitude, longitude),
            popup=location + ":  " + address,
            radius=5,
            fill=True,
            color='yellow',
            fill_opacity=1.
        )
    )

for (name, address, postalcode, latitude, longitude ) in df_climbing.itertuples(index=False):    
    outlets_fg.add_child(
        folium.features.CircleMarker(
            location=(latitude, longitude),
            popup=name + "," + address,
            radius=5,
            fill=True,
            color='blue',
            fill_opacity=1.
        )
    )
    
sg_map.add_child(outlets_fg)
sg_map.add_child(shortlisted_fg)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Most of our competitors' outlets are situated along main roads and clustered in the eastern parts of Singapore. A majority of our shortlisted locations are also situated close to main roads and three of them (L1 , L4 , L5) are located further from our competitors

# %%
# using Item-Item recommendation systems to compare competitors' locations to our shortlisted locations
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
#To normalise the dataframe on shortlisted locations for comparison
df_shortlisted_normalized = pd.DataFrame(
    scaler.fit_transform(df_shortlisted_venues_count),
    index=df_shortlisted_venues_count.index,
    columns=df_shortlisted_venues_count.columns
)

df_shortlisted_normalized.head()
# Out:
# Category  Bus Stop      Food  Metro Station  Shop & Service
# Location
# L1        0.000000  0.000000  0.0            0.000
# L2        0.500000  0.413793  0.0            0.500
# L3        1.000000  1.000000  0.0            0.375
# L4        0.500000  0.310345  1.0            0.500
# L5        0.333333  0.448276  1.0            1.000

# %% [markdown]
# ## 4. Results Section
# Based on our above analysis, our competitors' locations largely have a high number of 'Food' and 'Shop & Service' venues nearby. For our choice of the 5 shortlisted locations, we would be raking them by their proximity to 'Food' and 'Shop & Service' venues.

# %%
# Recommended location
df_recommend = df_shortlisted_normalized['Food'] + df_shortlisted_normalized['Shop & Service']
df_recommend = df_recommend.reset_index(name='Rating')
df_recommend = df_recommend.sort_values(by=['Rating'],ascending=[False])
df_recommend = df_recommend.reset_index(drop=True)
df_recommend
# Out:
#   Location    Rating
# 0  L5       1.448276
# 1  L3       1.375000
# 2  L2       0.913793
# 3  L4       0.810345
# 4  L1       0.000000

# %%
df_shortlisted_locations
# Out:
#   Location                                 Address  Latitude   Longitude
# 0  L1       The Grandstand, 200 Turf Club Rd        1.337892  103.793338
# 1  L2       IMM, 2 Jurong East Street 21            1.334815  103.746839
# 2  L3       KINEX, 11 Tanjong Katong Rd             1.314762  103.894726
# 3  L4       The Star Vista, 1 Vista Exchange Green  1.306763  103.788424
# 4  L5       Causeway Point, 1 Woodlands Square      1.435984  103.786013

# %%
df_shortlisted = pd.merge(
    df_shortlisted_locations,
    df_recommend,
    left_on='Location',
    right_on='Location'
)

df_shortlisted.sort_values('Rating', ascending=False, inplace=True)
df_shortlisted = df_shortlisted.reset_index(drop=True)
df_shortlisted
# Out:
#   Location                                 Address  Latitude   Longitude  \
# 0  L5       Causeway Point, 1 Woodlands Square      1.435984  103.786013
# 1  L3       KINEX, 11 Tanjong Katong Rd             1.314762  103.894726
# 2  L2       IMM, 2 Jurong East Street 21            1.334815  103.746839
# 3  L4       The Star Vista, 1 Vista Exchange Green  1.306763  103.788424
# 4  L1       The Grandstand, 200 Turf Club Rd        1.337892  103.793338
#
#      Rating
# 0  1.448276
# 1  1.375000
# 2  0.913793
# 3  0.810345
# 4  0.000000

# %%
print('Our shortlisted location is "{}" of address "{}".'.format(df_shortlisted.iat[0,0],df_shortlisted.iat[0,1]))
# Out:
# Our shortlisted location is "L5" of address "Causeway Point, 1 Woodlands Square".

# %% [markdown]
# ## 5. Discussion Section¶
# In this section, I would be discussing the observations I have noted and the recommendation that I can make based on the results.
#
# The shortlisted location is reasonable as it has the most number of Food' and 'Shop & Service' venues nearby compared to the others. Furthermore, it is also not located close to our competitors in the northern region of Singapore.
#
# To gather a rough feel of whether our initial list of 5 shortlisted locations is comparable to our competitors' venues, we performed a simple comparison based on the average of the number of nearby venues by category. The comparison result below shows that we have done a good job in shortlisting the initial 5 locations as the average number of nearby venues is comparable to or even exceeded that of our competitors.

# %%
df_venues_count.mean().to_frame(name='Average Count')
# Out:
#                 Average Count
# Category
# Bus Stop        2.916667
# Food            12.166667
# Metro Station   0.416667
# Shop & Service  5.583333

# %%
df_shortlisted_venues_count.mean().to_frame('Average Count')
# Out:
#                 Average Count
# Category
# Bus Stop        2.8
# Food            13.6
# Metro Station   0.4
# Shop & Service  7.6

# %% [markdown]
# ### 6. Conclusion
# Through the use of Foursquare location API, we have a better idea of the types of common venues surrounding our competitors' locations. Using that information, we apply the same criteria to compare our 5 shortlisted locations and concluded that L5: Causeway Point, 1 Woodlands Square is the best location to set up our indoor rock climbing facility.
